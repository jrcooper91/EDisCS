# %%
run ediscs_uvj_SFR_SN_bic.py

# %% [markdown]
# # HST Cycle 20 Matched to LDP with SN_Ha >5 & bic_diff >5

# %% [markdown]
# # 1301-1139 z = 0.4828

# %%
c1301(f_Ha,rf_J,rf_U,rf_V,rf_VJ,rf_UV,rf_m,logLHa,SFR,z,q,c)

# %% [markdown]
# # 1059-1253 z = 0.4564

# %%
c1059(f_Ha,rf_J,rf_U,rf_V,rf_VJ,rf_UV,rf_m,logLHa,SFR,z,q,c)

# %% [markdown]
# # 1138-1133 z = 0.4796

# %%
c1138(f_Ha,rf_J,rf_U,rf_V,rf_VJ,rf_UV,rf_m,logLHa,SFR,z,q,c)

# %% [markdown]
# # 1227-1138 z = 0.6357

# %%
c1227(f_Ha,rf_J,rf_U,rf_V,rf_VJ,rf_UV,rf_m,logLHa,SFR,z,q,c)

# %%
plt.figure(figsize=(18, 16), dpi= 80, facecolor='w', edgecolor='k')



x = [0,2]
y = [0,0]
plt.subplot(2,2,1)

h = open('/Users/jennifercooper/Documents/Gal_Ev/EDisCS/G102/test/1138_sn_bic>5_no_st.txt', 'r')
lines = h.readlines()[1:]
h.close()   
z_ldp     = []  
z_g       = []   
f_Ha      = []
f_Ha_e    = []
q_ldp     = [] 

for line in lines: 
    a = line.split()     
    z_ldp.append(float(a[14]))
    z_g.append(float(a[21]))
    f_Ha.append(float(a[3]))
    q_ldp.append(float(a[16]))
    f_Ha_e.append(float(a[4]))



z_ldp     = np.array(z_ldp)
z_g       = np.array(z_g)
f_Ha      = np.array(f_Ha)
f_Ha_log  = np.log10(f_Ha)
q_ldp     = np.array(q_ldp)
f_Ha_e    = np.array(f_Ha_e)
sn        = f_Ha/f_Ha_e


plt.scatter(z_ldp[np.where(q_ldp>2)],z_g[np.where(q_ldp>2)]-z_ldp[np.where(q_ldp>2)],c=f_Ha_log[np.where(q_ldp>2)])
cbar = plt.colorbar()
cbar.set_label("log(flux Ha)")
plt.xlabel('z LDP')
plt.ylabel('z grism - LDP')
plt.plot(x,y,color='black')
plt.title('1138: All matched sources with Ha Q_zLDP > 2')
plt.xlim(0,1)
plt.ylim(-0.2,0.3)

plt.subplot(2,2,2)

h = open('/Users/jennifercooper/Documents/Gal_Ev/EDisCS/G102/test/1227_sn_bic>5.txt', 'r')
lines = h.readlines()[1:]
h.close()   
z_ldp     = []  
z_g       = []   
f_Ha      = []
f_Ha_e    = []
q_ldp     = [] 

for line in lines: 
    a = line.split()     
    z_ldp.append(float(a[14]))
    z_g.append(float(a[21]))
    f_Ha.append(float(a[3]))
    q_ldp.append(float(a[16]))
    f_Ha_e.append(float(a[4]))



z_ldp     = np.array(z_ldp)
z_g       = np.array(z_g)
f_Ha      = np.array(f_Ha)
f_Ha_log  = np.log10(f_Ha)
q_ldp     = np.array(q_ldp)
f_Ha_e    = np.array(f_Ha_e)
sn        = f_Ha/f_Ha_e


plt.scatter(z_ldp[np.where(q_ldp>2)],z_g[np.where(q_ldp>2)]-z_ldp[np.where(q_ldp>2)],c=f_Ha_log[np.where(q_ldp>2)])
cbar = plt.colorbar()
#cbar.set_clim(-18,-10)
cbar.set_label("log(flux Ha)")
plt.xlabel('z LDP')
plt.ylabel('z grism - LDP')
plt.plot(x,y,color='black')
plt.title('1227: All matched sources with Ha Q_zLDP > 2')
plt.xlim(0,1)
plt.ylim(-0.2,0.75)

plt.subplot(2,2,3)

h = open('/Users/jennifercooper/Documents/Gal_Ev/EDisCS/G102/test/1301_sn_bic>5.txt', 'r')
lines = h.readlines()[1:]
h.close()   
z_ldp     = []  
z_g       = []   
f_Ha      = []
f_Ha_e    = []
q_ldp     = [] 

for line in lines: 
    a = line.split()     
    z_ldp.append(float(a[14]))
    z_g.append(float(a[21]))
    f_Ha.append(float(a[3]))
    q_ldp.append(float(a[16]))
    f_Ha_e.append(float(a[4]))



z_ldp     = np.array(z_ldp)
z_g       = np.array(z_g)
f_Ha      = np.array(f_Ha)
f_Ha_log  = np.log10(f_Ha)
q_ldp     = np.array(q_ldp)
f_Ha_e    = np.array(f_Ha_e)
sn        = f_Ha/f_Ha_e


plt.scatter(z_ldp[np.where(q_ldp>2)],z_g[np.where(q_ldp>2)]-z_ldp[np.where(q_ldp>2)],c=f_Ha_log[np.where(q_ldp>2)])
cbar = plt.colorbar()
#cbar.set_clim(-18,-10)
cbar.set_label("log(flux Ha)")
plt.xlabel('z LDP')
plt.ylabel('z grism - LDP')
plt.plot(x,y,color='black')
plt.title('1301: All matched sources with Ha Q_zLDP > 2')
plt.xlim(0.2,0.6)
plt.ylim(-0.2,0.3)

plt.subplot(2,2,4)

h = open('/Users/jennifercooper/Documents/Gal_Ev/EDisCS/G102/test/1059_sn_bic>5_no_st.txt', 'r')
lines = h.readlines()[1:]
h.close()   
z_ldp     = []  
z_g       = []   
f_Ha      = []
f_Ha_e    = []
q_ldp     = [] 

for line in lines: 
    a = line.split()     
    z_ldp.append(float(a[14]))
    z_g.append(float(a[21]))
    f_Ha.append(float(a[3]))
    q_ldp.append(float(a[16]))
    f_Ha_e.append(float(a[4]))



z_ldp     = np.array(z_ldp)
z_g       = np.array(z_g)
f_Ha      = np.array(f_Ha)
f_Ha_log  = np.log10(f_Ha)
q_ldp     = np.array(q_ldp)
f_Ha_e    = np.array(f_Ha_e)
sn        = f_Ha/f_Ha_e


plt.scatter(z_ldp[np.where(q_ldp>2)],z_g[np.where(q_ldp>2)]-z_ldp[np.where(q_ldp>2)],c=f_Ha_log[np.where(q_ldp>2)])
cbar = plt.colorbar()
#cbar.set_clim(-18,-10)
cbar.set_label("log(flux Ha)")
plt.xlabel('z LDP')
plt.ylabel('z grism - LDP')
plt.plot(x,y,color='black')
plt.title('1059: All matched sources with Ha Q_zLDP > 2')
plt.xlim(0,1)
plt.ylim(-0.2,0.75)

plt.show()
