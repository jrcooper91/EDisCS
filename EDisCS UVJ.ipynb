# %%
import pyfits 
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import numpy as np
import astropy 
from astropy import cosmology 
import math as mt

# %% [markdown]
# # EDisCS UVJ & Halpha

# %%
run ediscs_uvj.py

# %% [markdown]
# # 1059-1253 z = 0.4564

# %% [markdown]
# ![](G102/clusters/1059-1253/field.png)
# ![](G102/clusters/1059-1253/Ha_hist.png "HI")
# ![](G102/clusters/1059-1253/zhist.png "HI")
# ![](G102/clusters/1059-1253/z_match_Q_best.png "HI")
#
# ## Within 0.02
# ![](G102/clusters/1059-1253/field+cluster_0.02.png )

# %%
c1059(f_Ha,rf_J,rf_U,rf_V,rf_VJ,rf_UV)
# Out:
# <string>:241: RuntimeWarning: divide by zero encountered in log10

# %% [markdown]
# ## Field

# %%
f1059(f_Ha,rf_J,rf_U,rf_V,rf_VJ,rf_UV)
# Out:
# <string>:308: RuntimeWarning: divide by zero encountered in log10

# %% [markdown]
# ## a 1059-1253

# %% [markdown]
# ![](G102/clusters/1059-1253/Ha_hist_a.png "HI")

# %% [markdown]
# ## b 1059-1253

# %% [markdown]
# ![](G102/clusters/1059-1253/Ha_hist_b.png "HI")

# %% [markdown]
# ## c 1059-1253

# %% [markdown]
# ![](G102/clusters/1059-1253/Ha_hist_c.png "HI")

# %% [markdown]
# ## d 1059-1253

# %% [markdown]
# ![](G102/clusters/1059-1253/Ha_hist_d.png "HI")

# %% [markdown]
# # 1138-1133 z = 0.4796

# %% [markdown]
# ![](G102/clusters/1138_1133/field.png)
# ![](G102/clusters/1138_1133/Ha_hist.png "HI")
# ![](G102/clusters/1138_1133/zhist.png "HI")
# ![](G102/clusters/1138_1133/z_match_Q_best.png "HI")
# ## Within 0.02
# ![](G102/clusters/1138_1133/field+cluster_0.02.png )

# %%
c1138(f_Ha,rf_J,rf_U,rf_V,rf_VJ,rf_UV)

# %% [markdown]
# ## Field

# %%
f1138(f_Ha,rf_J,rf_U,rf_V,rf_VJ,rf_UV)

# %% [markdown]
# # 1227-1138 z = 0.6357

# %% [markdown]
# ![](G102/clusters/1227-1138/field.png)
# ![](G102/clusters/1227-1138/Ha_hist.png "HI")
# ![](G102/clusters/1227-1138/zhist.png "HI")
# ![](G102/clusters/1227-1138/z_match_Q_best.png "HI")
# ## Within 0.02
# ![](G102/clusters/1227-1138/field+cluster_0.02.png )

# %%
c1227(f_Ha,rf_J,rf_U,rf_V,rf_VJ,rf_UV)
# Out:
# <string>:106: RuntimeWarning: divide by zero encountered in log10

# %% [markdown]
# ## Field

# %%
f1227(f_Ha,rf_J,rf_U,rf_V,rf_VJ,rf_UV)
# Out:
# <string>:441: RuntimeWarning: divide by zero encountered in log10

# %% [markdown]
# # 1301-1139 z = 0.4828

# %% [markdown]
# ![](G102/clusters/1301-1139/field.png)
# ![](G102/clusters/1301-1139/Ha_hist.png "HI")
# ![](G102/clusters/1301-1139/zhist.png "HI")
# ![](G102/clusters/1301-1139/z_match_Q_best.png "HI")
# ## Within 0.02
# ![](G102/clusters/1301-1139/field+cluster_0.02.png )

# %%
c1301(f_Ha,rf_J,rf_U,rf_V,rf_VJ,rf_UV)
# Out:
# <string>:38: RuntimeWarning: divide by zero encountered in log10

# %% [markdown]
# ## Field

# %%
f1301(f_Ha,rf_J,rf_U,rf_V,rf_VJ,rf_UV)
# Out:
# <string>:510: RuntimeWarning: divide by zero encountered in log10

# %% [markdown]
# ## TO DO:
# ### Add Williams 2009 lines
